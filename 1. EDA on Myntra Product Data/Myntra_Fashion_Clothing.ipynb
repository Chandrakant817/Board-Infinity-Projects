# %% [markdown]
# # **Myntra Fashion Clothing**

# %% [markdown]
# **Problem Statement**
#
# The Myntra have shared the dataset with you to identify the **attributes to increase sales.**
# You are working as Lead consultant and your key role is to identify the parameters that are extremely important while making a decision.
# As a lead consultant you also have to show the results to your client and managers so it’s advised to create charts while you perform analysis and write down the insights in some separate sheet that you can refer later on.
# Some of the problems can be easily identified while solving the scenarios and tasks shared here but you are also required to further share your key points in the Conclusion.
# Exploratory Data Analysis (EDA) is an approach to analysing data sets to summarize the main characteristics of data by often using statistical graphs and other visualization methods such as by the use of statistical graphs.

# %% [markdown]
# # **Scenario1**
#
# You have been provided with 2 datasets. You will be learning here how to create the dataframe from 2 datasets and make some minor changes as required.
# Recognize the attributes carefully and make sure they are aligned in proper format.
#
# **Task1**
# 1.	Import all the relevant packages (Eg: Numpy, Seaborn...)
# 2.	Import the datasets into the python environment.
# 3.	Check the structure, statistics and other important functions. (Only observe the changes)
#
# **Task2**
# 1.	Create a new dataframe “df” by joining the 2 datasets
# 2.	Drop the duplicate data
# 3.	Check for missing values

# %%
# import the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# **Loading Both the Given Dataset to see the Data**

# %%
df1 = pd.read_csv("/content/product details.csv")
df1.head()
# Out:
#    ProductID                                        ProductName ProductBrand
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx

# %%
df2 = pd.read_csv("/content/products catalog.csv")
df2.head()
# Out:
#   Gender  Price (INR)  NumImages        ID  \
# 0  Women          593          5  10182131
# 1    Men         6396          5  10052169
# 2  Women          599          5  10168643
# 3    Men         1034          5  10155427
# 4    Men          477          3  10191059
#
#                                          Description PrimaryColor
# 0  Off-White printed woven A-line  top, has a rou...        White
# 1  Display: AnalogueMovement: QuartzPower source:...        Black
# 2  Blue printed knitted regular  top, has a high ...         Blue
# 3  Grey and Purple checked smart casual shirt, ha...         Grey
# 4  Beige and Brown striped beltReversible: NoStre...        Brown

# %%
# join the two Dataset i.e df1 and df2

# df = pd.concat([df1, df2], axis=1, join = "inner")

df=pd.merge(df1,df2, how='left', left_on='ProductID', right_on='ID')
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages        ID  \
# 0  Unisex        11745          7  10017413
# 1   Women         5810          7  10016283
# 2   Women          899          7  10009781
# 3     Men         5599          5  10015921
# 4     Men          759          5  10017833
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# ...

# %%
df.describe()
# Out:
#           ProductID   Price (INR)     NumImages            ID
# count  1.249100e+04  12491.000000  12491.000000  1.249100e+04
# mean   9.917160e+06   1452.660956      4.913698  9.917160e+06
# std    1.438006e+06   2118.503976      1.092333  1.438006e+06
# min    1.012060e+05     90.000000      1.000000  1.012060e+05
# 25%    1.006215e+07    649.000000      5.000000  1.006215e+07
# 50%    1.015463e+07    920.000000      5.000000  1.015463e+07
# 75%    1.021565e+07   1499.000000      5.000000  1.021565e+07
# max    1.027514e+07  63090.000000     10.000000  1.027514e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12491 entries, 0 to 12490
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
#  3   Gender        12491 non-null  object
#  4   Price (INR)   12491 non-null  int64
#  5   NumImages     12491 non-null  int64
#  6   ID            12491 non-null  int64
#  7   Description   12491 non-null  object
#  8   PrimaryColor  11597 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 975.9+ KB

# %% [markdown]
# **3.	Check for Duplicate values**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Drop the duplicate values...
df=df.drop_duplicates()

# %% [markdown]
# **4.	Check for Missing Values values**

# %%
df.isnull().sum()
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# ID                0
# Description       0
# PrimaryColor    894
# dtype: int64

# %%
# drop the ID column 

df=df.drop(['ID'], axis=1) 
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %% [markdown]
# # **Scenario2**
#
# You have successfully created the dataframe from the two input files.
# Here we will be processing cleaning operations and intro to brief analysis.
# Expected shape of the dataset: 12491 rows and 8 columns
#
# **Task**
# 1.	There is a column that needs string strip operation. Identify that and apply it.
# 2.	Fill the missing value by ‘Others’ in the column containing it
# 3.	Since all the column names are single word so you can convert the ‘Price (INR)’ also to single name ‘Price’.
# 4.	Analyse the Gender column and include your viewpoints how to make it useful.

# %% [markdown]
# **Shape of the dataset**

# %%
df.shape  ## here we get the expected shape
# Out:
# (12491, 8)

# %% [markdown]
# **1. There is a column that needs string strip operation. Identify that and apply it.**

# %%
# remove the spaces 
df.columns = df.columns.str.strip()

# %%
df["ProductBrand"].unique()
# Out:
# array(['DKNY', 'EthnoVogue', 'SPYKAR', 'Raymond', 'Parx', 'SHOWOFF',
#        'Kenneth Cole', 'Police', 'Vishudh', 'Being Human', 'Homesake',
#        'SEJ by Nisha Gupta', 'YAK YAK', 'PARFAIT', 'Michael Kors',
#        'HIGHLANDER', 'JEWEL JUNCTION', 'ID', 'Story@home',
#        'Gini and Jony', 'Sera', 'AccessHer', 'Alcis',
#        'Difference of Opinion', 'Tokyo Talkies', 'ANNA SUI',
#        'her by invictus', 'Soie', 'Lara Karen', 'Urban Dog', 'ahilya',
#        'VASTRAMAY', 'Campus Sutra', 'FIDO DIDO', 'MIAH Decor', 'BuckleUp',
#        'Peter England', 'AIGNER', 'Lady Lyka', 'Park Avenue', 'Roadster',
#        'U.S. Polo Assn. Denim Co.', 'Sweet Dreams', 'Kazo', 'Stylo Bug',
#        'Bvlgari', 'Qraa Men', 'GAS', 'WITH', 'ZUSH', 'JBN Creation',
#        'U.S. Polo Assn. Kids', 'DressBerry', 'ColorPlus', 'Lakme',
#        'Allen Solly Woman', 'Palm Tree', 'Arrow', 'DAVID BECKHAM',
#        'MANGO', 'Carrera', 'ROMEE', 'TAYHAA', 'Ishin', 'Shoe Couture',
# ...

# %%
df["PrimaryColor"].unique()
# Out:
# array([' Black', ' Beige', ' Pink', 'Blue', ' White', ' Brown',
#        ' Burgundy', ' Red', ' Green', nan, ' Maroon', ' Navy', ' Gold',
#        ' Yellow', ' Grey', ' Platinum', ' Silver', ' Khaki', ' Mustard',
#        ' Lavender', ' Matte', ' Rose', ' Charcoal', ' Purple', ' Orange',
#        ' Peach', ' Magenta', ' Bronze'], dtype=object)

# %% [markdown]
# **Applying Strip in ["PrimaryColor"]**

# %%
df["PrimaryColor"]=df["PrimaryColor"].str.strip()

# %%
df["PrimaryColor"][0:5].unique()
# Out:
# array(['Black', 'Beige', 'Pink', 'Blue', 'White'], dtype=object)

# %%
df.head(2)
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige

# %% [markdown]
# **2. Fill the missing value by ‘Others’ in the column containing it**

# %%
df.isnull().sum()
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64

# %%
# filling a null values using fillna(). 
# Only PrimaryColor column having Missing values, filling missing values with "Others"

df['PrimaryColor']=df["PrimaryColor"].fillna('Others')
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %%
df.isnull().sum()
# Out:
# ProductID       0
# ProductName     0
# ProductBrand    0
# Gender          0
# Price (INR)     0
# NumImages       0
# Description     0
# PrimaryColor    0
# dtype: int64

# %% [markdown]
# **3. Since all the column names are single word so you can convert the ‘Price (INR)’ also to single name ‘Price’.**

# %%
# rename 'Price (INR)' column to 'Price'
df.rename(columns={'Price (INR)': 'Price'}, inplace=True)

# %%
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %% [markdown]
# **4. Analyse the Gender column and include your viewpoints how to make it useful.**

# %%
df["Gender"].value_counts()
# Out:
# Women          5126
# Men            4591
# Unisex         1188
# Boys           1100
# Girls           440
# Unisex Kids      46
# Name: Gender, dtype: int64

# %%
## Gender

plt.figure(figsize = (8,6))
sns.countplot(data=df,x='Gender')
plt.xlabel("Gender",fontsize = 12)
plt.show()

# %% [markdown]
# Women has the Highest Number of Count of 5126 i.e (41.04%)
#
# Men has total 4591 number of count i.e (36.75%)
#
# Least having Unisex Kids of 46 i.e (0.3%)

# %%
plt.figure(figsize=(6,6))
df["Gender"].value_counts().plot(kind = "pie",autopct = "%0.2f%%")
plt.show()

# %% [markdown]
# **Expected Shape of Dataset**

# %%
df.shape
# Out:
# (12491, 8)

# %% [markdown]
# # **Scenario3**
# So far we have learnt the basics of the dataset and cleaned it as required. Over here you are going to perform deep analysis of the dataset with the help of data manipulation tricks as well as visualize the results.
# This is the most time consuming tasks and make sure you do perform proper analysis method. While answering the question against all the tasks, it will be great if you can create charts to support it also.
# Expected shape of the dataset: 12491 rows and 8

# %% [markdown]
# **Task1**
# 1.	Univariate analysis of each variable
# 2.	Bivariate Analysis of categorical vs numerical variables (Take target variable as fixed variable here)
# 3.	Multivariate Analysis of categorical and numerical variables
# 4.	Check distribution of variables

# %%
Numerical_col = df.columns[df.dtypes != "object"]
Categorical_col = df.columns[df.dtypes == "object"]

print(Numerical_col)
print(Categorical_col)
# Out:
# Index(['ProductID', 'Price', 'NumImages'], dtype='object')
# Index(['ProductName', 'ProductBrand', 'Gender', 'Description', 'PrimaryColor'], dtype='object')

# %% [markdown]
# **1. (i) Implementing Univarient Analysys for Categorical Data**

# %% [markdown]
# **a. Product Name**

# %%
# products Name having the most variety 

df["ProductName"].value_counts().head(10)
# Out:
# Parx Men Blue Slim Fit Checked Casual Shirt                           16
# ZHEIA Women Blue Skinny Fit Mid-Rise Clean Look Stretchable Jeans     15
# Roadster Men Blue Skinny Fit Mid-Rise Clean Look Stretchable Jeans    14
# Sonari Pack of 2 Full-Coverage Bras                                   14
# Roadster Men Blue Slim Fit Mid-Rise Clean Look Stretchable Jeans      13
# Sonari Pack of 2 Full-Coverage Bras celina                            12
# JEWEL JUNCTION Silver-Toned Geometric Cufflinks                       12
# Next Look Men Blue Slim Fit Self Design Formal Shirt                  12
# Parx Men Blue Slim Fit Printed Casual Shirt                           11
# Sonari Pack of 2 Full-Coverage T-shirt Bras cristina                  11
# Name: ProductName, dtype: int64

# %% [markdown]
# Analysing the Top 10 Product Name Preferred by Customers.
#
# Maximum ProductName: "Parx Men Blue Slim Fit Checked Casual Shirt" having Total count of 16

# %%
from wordcloud import WordCloud
     
df.groupby(["ProductName"]).count().head(10)
# Out:
#                                                     ProductID  ProductBrand  \
# ProductName
# 109F Women Blue Dyed Straight Maxi Skirt                    1             1
# 20Dresses Women Maroon Solid A-Line Dress                   1             1
# 20Dresses Women White Pure Cotton Self-Striped ...          1             1
# 20Dresses Women White Self-Striped A-Line Dress             1             1
# 22 KT Gold-Plated & Silver-Toned Textured Cuff ...          1             1
# 612 League Boys Grey Solid Joggers                          1             1
# 612 league Boys Blue Regular Fit High-Rise Clea...          3             3
# 612 league Boys Blue Regular Fit Mid-Rise Clean...          1             1
# 612 league Boys Blue Solid Polo Collar T-shirt              1             1
# 612 league Boys Blue Solid Track Pants                      1             1
#
#                                                     Gender  Price  NumImages  \
# ProductName
# ...

# %%
ProductName1=df["ProductName"].tolist()
#ProductName1

# %%
#convert the list into single string
ProductName2=" ".join(ProductName1)

#ProductName2

# %%
plt.figure(figsize=(10,10))
plt.imshow(WordCloud().generate(ProductName2))

# %%
plt.figure(figsize = (8,6))
sns.countplot(data=df[0:20],y='ProductName')
plt.xlabel("ProductName")
plt.show()

# %% [markdown]
# **b. Product Brand**

# %%
df["ProductBrand"].value_counts().head(10)
# Out:
# Indian Terrain          971
# Puma                    345
# Pepe Jeans              340
# AURELIA                 307
# Flying Machine          301
# W                       261
# U.S. Polo Assn. Kids    234
# Roadster                232
# GAP                     216
# WROGN                   175
# Name: ProductBrand, dtype: int64

# %%
plt.figure(figsize = (10,6))
#sns.countplot(data=df,y='ProductBrand')
sns.countplot(x='ProductBrand', order=df['ProductBrand'].value_counts().iloc[:5].index, data=df)
plt.xlabel("ProductBrand")
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# Analysing the Top 10 Product Brand Preferred by Customers.
#
# Maximum ProductBrand: "Indian Terrain" having Total count of 971
#
# Second Maximum is "Puma" having total count of 345

# %% [markdown]
# **c. Gendre**

# %%
plt.figure(figsize = (8,6))
sns.countplot(data=df,x='Gender')
plt.xlabel("Gender",fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(7,7))
explode = [0.02,0.01,0.01,0.01,0.01,0.01]
df["Gender"].value_counts().plot(kind = "pie",autopct = "%0.2f%%",explode = explode)
plt.show()

# %% [markdown]
# Women has the Highest Number of Count of 5126 i.e (41.04%)
#
# Men has total 4591 number of count i.e (36.75%)
#
# Least having Unisex Kids of 46 i.e (0.3%)

# %% [markdown]
# **d. Description**

# %%
df["Description"].value_counts().head(5)
# Out:
# Blue medium wash 5-pocket mid-rise jeans, clean look, heavy fade, has a button and zip closure, and waistband with belt loops                                                                                                                                             54
# Blue medium wash 5-pocket mid-rise jeans, clean look, light fade, has a button and zip closure, and waistband with belt loops                                                                                                                                             47
# Black printed T-shirt, has a round neck, and short sleeves                                                                                                                                                                                                                36
# ...

# %% [markdown]
# **e. PrimaryColor**

# %%
df["PrimaryColor"].value_counts()
# Out:
# Blue        3443
# Black       1640
# Red         1543
# Green        908
# Others       894
# White        880
# Grey         684
# Brown        473
# Yellow       406
# Pink         391
# Gold         236
# Beige        236
# Maroon       187
# Orange       130
# Silver       111
# Purple        65
# Burgundy      64
# Khaki         56
# Navy          54
# Lavender      19
# Matte         17
# Mustard       15
# Magenta       13
# Charcoal      10
# Rose           8
# Platinum       3
# Bronze         3
# Peach          2
# Name: PrimaryColor, dtype: int64

# %%
plt.figure(figsize = (10,6))
#sns.countplot(data=df,y='ProductBrand')
sns.countplot(x='PrimaryColor', order=df['PrimaryColor'].value_counts().iloc[:5].index, data=df)
plt.xlabel("PrimaryColor")
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# Analysing the Most Preferred Colors by Customers.
#
# 1. Most of the cusomet preferred Blue color over other color then Black then Red and so on..
# 2. Least preferred color is Peach

# %% [markdown]
# **1. (ii) Implementing Univarient Analysys for Numerical Data**

# %%
df["Price"].value_counts().head(5)
# Out:
# 699     510
# 1299    464
# 1999    312
# 599     295
# 899     254
# Name: Price, dtype: int64

# %%
df["Price"].describe()
# Out:
# count    12491.000000
# mean      1452.660956
# std       2118.503976
# min         90.000000
# 25%        649.000000
# 50%        920.000000
# 75%       1499.000000
# max      63090.000000
# Name: Price, dtype: float64

# %%
plt.figure(figsize = (8,6))
sns.distplot(df["Price"])
plt.xlabel("Price",fontsize = 12)
plt.show()

# %% [markdown]
# Price Distribution Plot:
# 1. min price: 90
# 2. midium Price: 920
# 3. Maximum Price: 63090
#
# Price Distribution Plot : It follows Right Skewed Curve (It is a Log Normal Distribution (+ve Skewed))

# %%
df["NumImages"].value_counts().head(5)
# Out:
# 5    7134
# 4    1693
# 3    1211
# 6    1080
# 7    1057
# Name: NumImages, dtype: int64

# %%
df["NumImages"].describe()
# Out:
# count    12491.000000
# mean         4.913698
# std          1.092333
# min          1.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.000000
# max         10.000000
# Name: NumImages, dtype: float64

# %%
plt.figure(figsize = (8,6))
sns.distplot(df["NumImages"])
plt.xlabel("NumImages",fontsize = 12)
plt.show()

# %% [markdown]
# NumImages Distribution Plot:
#
# 1. min NumImages: 1
# 2. midium NumImages: 5
# 3. Maximum NumImages: 10
#
# "5 NumImages has the Highest Number of Count of 7134"

# %% [markdown]
# **2. Bivariate Analysis of categorical vs numerical variables**

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# There is no correlation between features

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.boxplot(x='Gender',y='Price',data=df,palette='rainbow')
plt.xticks(rotation = 90)

plt.subplot(2,2,2)
plt.bar(df["PrimaryColor"], df["NumImages"], align='edge', width=0.4)
plt.xticks(rotation = 90)

plt.subplot(2,2,3)
sns.stripplot(x="Gender", y="NumImages", data=df)
plt.xticks(rotation = 90)

plt.subplot(2,2,4)
sns.barplot(x = "PrimaryColor",y = "Price",data=df)
plt.xticks(rotation = 90)

plt.show()

# %% [markdown]
# 1. BoxPlot (Gender Vs Price): It shows the Outliers of the data and Shows the Quartile ranges in each feature. Only few records having price greater then 50000.
#
# 2. Barplot (PrimaryColor Vs NumImages): Pink, Green and Yellow Color having highest number of Images while Peach color has lowest Num of Images
#
# 3. stripplot (Gender Vs NumImages): Women has the Highest Number of Images of 10 (this is max). Unisex Kids and Girls has the least Number of Images.
#
# 4. Barplot (PrimaryColor and Price): Silver and Rose this both color having the highest Price which is greater than 2500. Leas color is Peach

# %%
df.groupby("Gender").sum()["Price"].sort_values(ascending=False).plot(kind="bar",color = "green")
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# The total price of purchases has been calculated and grouped by gender. Men have the highest total price of purchases, while Unisex Kids have the lowest total price of purchases.

# %%
df.groupby('Gender').mean()["Price"].sort_values(ascending = False).plot(kind="bar",color = "green")
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# The minimum price of purchases has been calculated and grouped by gender. It indicates that Unisex has the highest minimum price, while BoysKids have the lowest minimum price.

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df,x='PrimaryColor',hue='Gender')
plt.xlabel("Primary Color",fontsize = 15)
plt.show()

# %% [markdown]
#  The primary color Blue has the highest count of all the gender categories.

# %%
df.groupby("ProductBrand").sum()["Price"].sort_values(ascending=False).head(10)
# Out:
# ProductBrand
# Indian Terrain        938042
# Puma                  931545
# Titan                 633252
# Calvin Klein Jeans    486119
# DKNY                  429620
# W                     393944
# Geox                  390918
# SEIKO                 331900
# AURELIA               317708
# GAP                   303364
# Name: Price, dtype: int64

# %%
plt.figure(figsize=(10,6))
df.groupby(['ProductBrand'])['Price'].sum().sort_values(ascending=False).head(10).plot(kind="bar",color = "orange")
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# The "Indian Terrain" ProductBrand has the highest sum of price among all the product brands, followed by Puma and so on.

# %%
plt.figure(figsize=(12,6))
df.groupby("ProductName").sum()['Price'].sort_values().head(10).plot(kind="barh",color = "brown")
plt.ylabel("Product Name",fontsize = 12)
plt.show()

# %% [markdown]
# The Product Name "Organic Harvest Unisex sulphate free oil control face wash 100g" and "Organic Harvest Unisex sulphate free Acne control face wash 100g" has the highest sum of price among all the products.

# %% [markdown]
# **3. Multivarient Analysis**

# %%
df.corr()
# Out:
#            ProductID     Price  NumImages
# ProductID   1.000000 -0.015126   0.058085
# Price      -0.015126  1.000000   0.127023
# NumImages   0.058085  0.127023   1.000000

# %%
# constructing a heatmap to understand the correlation

plt.figure(figsize=(7,5))
sns.heatmap(df.corr(), cmap='Blues',annot = True)
plt.show()

# %% [markdown]
# Price and NumImages has the Positive Correlation
#
# Price and ProductID has the Negative Correlation or No Correlation

# %%
plt.figure(figsize=(15,8))
multi_var1 = df.groupby(['ProductBrand','Gender']).sum()["Price"].reset_index().sort_values(by=['Price'], ascending=False).head(15)
multi_var1
# Out:
#            ProductBrand  Gender   Price
# 338      Indian Terrain     Men  747095
# 129  Calvin Klein Jeans     Men  486119
# 554                Puma     Men  437178
# 700               Titan     Men  427623
# 173                DKNY  Unisex  411965
# 755                   W   Women  393944
# 555                Puma  Unisex  385931
# 21              AURELIA   Women  317708
# 760               WROGN     Men  297460
# 409               Lavie   Women  294894
# 519              PRESTO  Unisex  285508
# 284                Geox     Men  250253
# 527         Park Avenue     Men  230943
# 411               Levis     Men  217606
# 337      Indian Terrain    Boys  190947

# %%
plt.figure(figsize=(18,6))
sns.barplot(x='ProductBrand',y='Price', data=multi_var1, hue='Gender')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# We can conclude that a grouped bar chart has been created to visualize the top 10 product brands by sum of total price, with bars grouped by gender. The output of this code indicates the product brands that have the highest sum of total price for each gender.

# %%
plt.figure(figsize=(15,8))
multi_var2 = df.groupby(['ProductName','Gender']).sum()["Price"].reset_index().sort_values(by=['Price'], ascending=False).head(10)
multi_var2
# Out:
#                                             ProductName  Gender  Price
# 3160  Garmin Unisex Black Forerunner 945 Smartwatch ...  Unisex  63090
# 3161  Garmin Unisex Blue Forerunner 945 Smartwatch 0...  Unisex  63090
# 5727             MOVADO Men Black Analogue Watch 607243     Men  58854
# 5729            MOVADO Women Blue Analogue Watch 607268   Women  56192
# 1886               DKNY Unisex Black Medium Trolley Bag  Unisex  50495
# 1882  DKNY Unisex Black & Grey Printed Large Trolley...  Unisex  44375
# 1322  Calvin Klein Jeans Men Blue Slim Fit Mid-Rise ...     Men  42443
# 7183  Presto Multicolored Printed Hand Tufted Wool C...  Unisex  41062
# 1884                DKNY Unisex Black Cabin Trolley Bag  Unisex  35465
# 6548  PRESTO Blue and Brown Printed Handmade Anti-Sk...  Unisex  35396

# %%
plt.figure(figsize=(12,6))
sns.barplot(y='ProductName',x='Price', data=multi_var2, hue='Gender')
plt.show()

# %% [markdown]
# We can conclude that a horizontal grouped bar chart has been created to visualize the sum of prices for each product by gender. The output of this code indicates the top 10 product names for each gender based on the sum of prices.

# %% [markdown]
# **Check the Distribution**

# %%
plt.figure(figsize = (8,6))
sns.distplot(df["Price"])
plt.xlabel("Price",fontsize = 12)
plt.show()

# %% [markdown]
# Price Distribution Plot:
# 1. min price: 90
# 2. midium Price: 920
# 3. Maximum Price: 63090
#
# Price Distribution Plot : It follows Right Skewed Curve (It is a Log Normal Distribution (+ve Skewed))

# %%
plt.figure(figsize = (8,6))
sns.distplot(df["NumImages"])
plt.xlabel("NumImages",fontsize = 12)
plt.show()

# %% [markdown]
# NumImages Distribution Plot:
#
# 1. min NumImages: 1
# 2. midium NumImages: 5
# 3. Maximum NumImages: 10
#
# "5 NumImages has the Highest Number of Count of 7134"

# %% [markdown]
# **Task2**
# 1.	Create a new Column “NewGender” to analyse further its distribution. Going forward we will consider this group for tasks
# Logic Applied
#
#  i.	Include Boys & Men as Men
#
#  ii.	Include Girls & Women as Women
#
#  iii.	Include Unisex & Unisex Kids as Unisex
#
# 2.	Complete the analysis of NewGender along with other categorical cols.

# %%
df["Gender"].value_counts()
# Out:
# Women          5126
# Men            4591
# Unisex         1188
# Boys           1100
# Girls           440
# Unisex Kids      46
# Name: Gender, dtype: int64

# %%
n = [] #empty list for storing the 3 values ["Womsn","Men" and "Unisex"]

for i in df.Gender:
    if i == 'Women' or i == 'Girls':
        n.append('Women')
    elif i == 'Men' or i == 'Boys':
        n.append('Men')
    else:
        n.append('Unisex')
        
df['NewGender'] = n

# %%
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %% [markdown]
# **analysis of NewGender along with other categorical cols**

# %%
df["NewGender"].value_counts()
# Out:
# Men       5691
# Women     5566
# Unisex    1234
# Name: NewGender, dtype: int64

# %%
## Gender
plt.figure(figsize = (8,6))
sns.countplot(data=df,x='NewGender')
plt.xlabel("NewGender",fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(6,6))
explode = [0.02,0.01,0.01]
df["NewGender"].value_counts().plot(kind = "pie",autopct = "%0.2f%%",explode = explode)
plt.show()

# %% [markdown]
# Men has the Highest Number of Count of 5691 i.e (45.56%)
#
# Women has total 5566 number of count i.e (44.56%)
#
# Least having Unisex total number of count of 1234 i.e (9.88%)

# %%
plt.figure(figsize=(15,8))
new1 = df.groupby(['ProductBrand','NewGender']).sum()["Price"].reset_index().sort_values(by=['Price'], ascending=False).head(15)
new1
# Out:
#            ProductBrand NewGender   Price
# 328      Indian Terrain       Men  938042
# 128  Calvin Klein Jeans       Men  486119
# 536                Puma       Men  437178
# 680               Titan       Men  427623
# 172                DKNY    Unisex  411965
# 731                   W     Women  393944
# 537                Puma    Unisex  392677
# 20              AURELIA     Women  317708
# 736               WROGN       Men  297460
# 399               Lavie     Women  294894
# 503              PRESTO    Unisex  285508
# 518          Pepe Jeans       Men  261655
# 277                Geox       Men  250253
# 511         Park Avenue       Men  230943
# 238      Flying Machine       Men  228632

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='ProductBrand',y='Price', data=new1, hue='NewGender')
# Out:
# <Axes: xlabel='ProductBrand', ylabel='Price'>

# %% [markdown]
# We can conclude that a grouped bar chart has been created to visualize the top 15 product brands by sum of total price, with bars grouped by Newgender. The output of this code indicates the product brands that have the highest sum of total price for each Newgender.

# %%
plt.figure(figsize=(15,8))
new2 = df.groupby(['ProductName','NewGender']).sum()["Price"].reset_index().sort_values(by=['Price'], ascending=False).head(15)
new2
# Out:
#                                             ProductName NewGender  Price
# 3160  Garmin Unisex Black Forerunner 945 Smartwatch ...    Unisex  63090
# 3161  Garmin Unisex Blue Forerunner 945 Smartwatch 0...    Unisex  63090
# 5727             MOVADO Men Black Analogue Watch 607243       Men  58854
# 5729            MOVADO Women Blue Analogue Watch 607268     Women  56192
# 1886               DKNY Unisex Black Medium Trolley Bag    Unisex  50495
# 1882  DKNY Unisex Black & Grey Printed Large Trolley...    Unisex  44375
# 1322  Calvin Klein Jeans Men Blue Slim Fit Mid-Rise ...       Men  42443
# 7183  Presto Multicolored Printed Hand Tufted Wool C...    Unisex  41062
# 1884                DKNY Unisex Black Cabin Trolley Bag    Unisex  35465
# 6548  PRESTO Blue and Brown Printed Handmade Anti-Sk...    Unisex  35396
# 7967   SEIKO Solar Women Silver Analogue watch SUP428P1     Women  34500
# 7970        SEIKO White Round Solid Analogue Wall Clock    Unisex  34400
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='ProductName',x='Price', data=new2, hue='NewGender')
# Out:
# <Axes: xlabel='Price', ylabel='ProductName'>

# %% [markdown]
# We can conclude that a horizontal grouped bar chart has been created to visualize the sum of prices for each product by Newgender. The output of this code indicates the top 15 product names for each Newgender based on the sum of prices.

# %% [markdown]
# **Task3**
# 1.	Create a new Column “DescriptionLength” to analyse further its distribution.
# Logic Applied
# i.	Each record of DescriptionLength is equal to the number of chars in Description
#
# 2.	Complete the analysis of DescriptionLength along with other categorical cols.
# 3.	Isn’t it important to check if attribute information is also included in Description? Complete this task before answering it.

# %%
df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %%
df["Description"].head(10)
# Out:
# 0    Black and grey printed medium trolley bag, sec...
# 1    Beige & Grey made to measure kurta with churid...
# 2    Pink coloured wash 5-pocket high-rise cropped ...
# 3    Blue self-design bandhgala suitBlue self-desig...
# 4    Brown and off-white printed casual shirt, has ...
# 5    Brown solid low-rise regular shorts, has four ...
# 6    Blue checked casual shirt, has a spread collar...
# 7    Burgundy coloured wash 5-pocket high-rise jean...
# 8        Brown solid regular trousers regular trousers
# 9    Black solid large trolley bag, secured with a ...
# Name: Description, dtype: object

# %%
df['DescriptionLength'] = df['Description'].apply(len)

# %%
df['DescriptionLength']
# Out:
# 0        401
# 1        620
# 2        133
# 3        340
# 4        122
#         ...
# 12486    280
# 12487    210
# 12488     84
# 12489     50
# 12490    186
# Name: DescriptionLength, Length: 12491, dtype: int64

# %%
len1 = df['Description'][0]
len1
# Out:
# 'Black and grey printed medium trolley bag, secured with a TSA lockOne handle on the top and one on the side, has a trolley with a retractable handle on the top and four corner mounted inline skate wheelsOne main zip compartment, zip lining, two compression straps with click clasps, one zip compartment on the flap with three zip pocketsWarranty: 5 yearsWarranty provided by Brand Owner / Manufacturer'

# %%
len(len1)
# Out:
# 401

# %%
df_Description_len = pd.concat([df, df['DescriptionLength']], axis=1)
df_Description_len.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender  \
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %%
df_Description_len.shape
# Out:
# (12491, 11)

# %% [markdown]
# **Checking the Distribution of all the Numerical Columns**

# %%
df_Description_len["DescriptionLength"].describe()
# Out:
#        DescriptionLength  DescriptionLength
# count       12491.000000       12491.000000
# mean          159.185173         159.185173
# std           155.039114         155.039114
# min             7.000000           7.000000
# 25%            91.000000          91.000000
# 50%           119.000000         119.000000
# 75%           171.000000         171.000000
# max          3670.000000        3670.000000

# %%
plt.figure(figsize = (8,5))
sns.distplot(df_Description_len["DescriptionLength"])
plt.xlabel("DescriptionLength",fontsize = 12)
plt.show()

# %% [markdown]
# DescriptionLength Distribution Plot:
#
# Total DescriptionLength Count: 12491
#
# 1. min descriptionLength: 7
# 2. medium descriptionLength: 119
# 3. Maximum descriptionLength: 3670
#
# DescriptionLength Distribution Plot : It follows Right Skewed Curve (It is a Log Normal Distribution (+ve Skewed))

# %%
Num_Column = df.columns[df.dtypes != "object"]
Num_Column
# Out:
# Index(['ProductID', 'Price', 'NumImages', 'DescriptionLength'], dtype='object')

# %%
df[Num_Column].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12491 entries, 0 to 12490
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ProductID          12491 non-null  int64
#  1   Price              12491 non-null  int64
#  2   NumImages          12491 non-null  int64
#  3   DescriptionLength  12491 non-null  int64
# dtypes: int64(4)
# memory usage: 746.0 KB

# %%
plt.figure(figsize=(15,10))
plotnumber = 1

for column in df[Num_Column]:
  if plotnumber <= 5:
    ax = plt.subplot(2,2,plotnumber)
    sns.distplot(df[Num_Column][column])
    plt.xlabel(column,fontsize = 15)
  plotnumber+=1
plt.show()

# %% [markdown]
# ### **WordCloud for Description feature**

# %%
df.groupby(["Description"]).count().head(10)

Description1=df["Description"].tolist()
#ProductName1
#convert the list into single string

# %%
Description_1=" ".join(Description1)
#Description_1

# %%
plt.figure(figsize=(10,10))
plt.imshow(WordCloud().generate(Description_1))

# %% [markdown]
# **Product Name and DescriptionLength**

# %%
# Product Name
# Description length by top 10 products.
plt.figure(figsize=(15,8))
des_1 = df.groupby('ProductName').mean()["DescriptionLength"].reset_index().sort_values(by=['DescriptionLength'], ascending=False).head(15)
des_1
# Out:
#                                             ProductName  DescriptionLength
# 7170                           Plum Set Of 3 Beauty Kit             3670.0
# 7572                  Qraa Men Intense Acne Therapy Kit             3010.0
# 7168                         Plum Pack of 3 Beauty Kits             2565.0
# 6433  Organic Harvest Unisex Radiance Face Elixir Cr...             2255.0
# 7171  Plum Set Of Green Tea Face Mist & Kajal with S...             2244.0
# 6199     Namyaa Intimate Hygiene Wash & Whitening Serum             2223.0
# 7166  Plum Olive & Macadamia Mega Moisturizing Susta...             2161.0
# 7174    Plum Women Pack of Face Moisturiser & Hair Mask             2102.0
# 7173  Plum Women Green Tea Skin Clarifying Concentra...             1823.0
# 7165         Plum Night Gel & Glow Restore Face Oil Set             1687.0
# 6425  Organic Harvest Sulphate Free 6-In-1 Face Wash...             1627.0
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='DescriptionLength',y='ProductName', data=des_1)
plt.show()

# %% [markdown]
# Description Length by Top 15 Product Name
#
# > We can conclude that the top 15 products Name with the highest average description length

# %% [markdown]
# **ProductBrand with DescriptionLenght**

# %%
# Product Name

plt.figure(figsize=(15,8))
des_2 = df.groupby('ProductBrand').mean()["DescriptionLength"].reset_index().sort_values(by=['DescriptionLength'], ascending=False).head(15)
des_2
# Out:
#              ProductBrand  DescriptionLength
# 440                  Plum        1667.533333
# 599                  VLCC        1464.000000
# 415       Organic Harvest        1304.375000
# 394                Namyaa        1198.000000
# 151  Daily Life Forever52        1197.058824
# 452              Qraa Men        1171.600000
# 594              Unshaven        1021.000000
# 227                Garmin         954.000000
# 656                  boAt         880.000000
# 119                Carven         865.000000
# 652                aramis         854.000000
# 59              BOLLYGLOW         815.333333
# 558                 Taavi         792.846154
# 604              VarEesha         778.666667
# 202                Foolzy         776.000000

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='DescriptionLength',y='ProductBrand', data=des_2)
plt.show()

# %% [markdown]
# Description Length by Top 15 Products Brand
#
# > We can conclude that the top 15 product brands with the highest average description length

# %% [markdown]
# # **Thank You**
